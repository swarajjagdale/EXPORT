# %%
import pandas as pd
import os

# %%
df = pd.read_csv("./results.csv")

# %%
df
# Out:
#                      ROUGE-Type  Task Name  System Name  Avg_Recall  \
# 0       ROUGE-L+StopWordRemoval      33090  SYSSUMM.TXT     0.41007
# 1       ROUGE-1+StopWordRemoval      33090  SYSSUMM.TXT     0.49954
# 2       ROUGE-2+StopWordRemoval      33090  SYSSUMM.TXT     0.31832
# 3     ROUGE-SU4+StopWordRemoval      33090  SYSSUMM.TXT     0.39097
# 4       ROUGE-L+StopWordRemoval      30817  SYSSUMM.TXT     0.45027
# ...                         ...        ...          ...         ...
# 1447  ROUGE-SU4+StopWordRemoval      32217  SYSSUMM.TXT     0.49494
# 1448    ROUGE-L+StopWordRemoval      31008  SYSSUMM.TXT     0.39588
# 1449    ROUGE-1+StopWordRemoval      31008  SYSSUMM.TXT     0.46177
# 1450    ROUGE-2+StopWordRemoval      31008  SYSSUMM.TXT     0.29370
# 1451  ROUGE-SU4+StopWordRemoval      31008  SYSSUMM.TXT     0.36334
#
#       Avg_Precision  Avg_F-Score  Num Reference Summaries
# 0           0.27261      0.32750                        4
# 1           0.36442      0.42141                        4
# 2           0.16896      0.22075                        4
# 3           0.15963      0.22670                        4
# 4           0.28198      0.34679                        3
# ...             ...          ...                      ...
# 1447        0.08508      0.14520                        4
# 1448        0.49333      0.43926                        3
# 1449        0.53373      0.49515                        3
# 1450        0.27018      0.28145                        3
# 1451        0.26275      0.30496                        3
#
# [1452 rows x 7 columns]

# %%
df2 = pd.read_csv("./results.csv")

# %%
import pandas as pd

# Assuming your data is in a CSV file named 'your_dataset.csv'
# If it's in a different format, adjust the read function accordingly
df = pd.read_csv('./results.csv')

# Separate data for each ROUGE category
rouge_l_data = df[df['ROUGE-Type'] == 'ROUGE-L+StopWordRemoval']
rouge_1_data = df[df['ROUGE-Type'] == 'ROUGE-1+StopWordRemoval']
rouge_2_data = df[df['ROUGE-Type'] == 'ROUGE-2+StopWordRemoval']
rouge_su4_data = df[df['ROUGE-Type'] == 'ROUGE-SU4+StopWordRemoval']

# Calculate averages for each category
avg_rouge_l = rouge_l_data[['Avg_Recall', 'Avg_Precision', 'Avg_F-Score']].mean()
avg_rouge_1 = rouge_1_data[['Avg_Recall', 'Avg_Precision', 'Avg_F-Score']].mean()
avg_rouge_2 = rouge_2_data[['Avg_Recall', 'Avg_Precision', 'Avg_F-Score']].mean()
avg_rouge_su4 = rouge_su4_data[['Avg_Recall', 'Avg_Precision', 'Avg_F-Score']].mean()

# Print the results with labels
print("Average for ROUGE-L:")
print(avg_rouge_l)

print("\nAverage for ROUGE-1:")
print(avg_rouge_1)

print("\nAverage for ROUGE-2:")
print(avg_rouge_2)

print("\nAverage for ROUGE-SU4:")
print(avg_rouge_su4)
# Out:
# Average for ROUGE-L:
# Avg_Recall       0.436203
# Avg_Precision    0.361502
# Avg_F-Score      0.387324
# dtype: float64
#
# Average for ROUGE-1:
# Avg_Recall       0.492973
# Avg_Precision    0.399313
# Avg_F-Score      0.428867
# dtype: float64
#
# Average for ROUGE-2:
# Avg_Recall       0.317421
# Avg_Precision    0.187568
# Avg_F-Score      0.228217
# dtype: float64
#
# Average for ROUGE-SU4:
# Avg_Recall       0.392297
# Avg_Precision    0.177267
# Avg_F-Score      0.236677
# dtype: float64
